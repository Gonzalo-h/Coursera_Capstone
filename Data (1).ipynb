# %% [markdown]
# # Data obtained and used for the 'Battle of the neighborhoods' project
#
# **-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# To obtain the data that enables the analyzing of all of the mentioned aspects, this study has proceded as it follows:

# %% [markdown]
# ## 1. Datasets used to extract data that will be studied

# %% [markdown]
# ### Where have we obtained all this data from?
#
#
# To perform the correct analysis of this study, it is necessary to find correct datasets that define every parameter used. For this study it will be firstly used websites like wikipedia to
# gather, in this case, information of number and location of each neighborhood in both cities chosen to be analyzed.
#
# Having the divisions of each city in their respective neighborhoods and the precise locations (in matter of latitude and longitude) it is now necessary to gather data involving the parameters
# chosen to perform the study: bars, restaurants, social locals, museums, parks, etc. For this purpose and, as suggested in the project instructions, it will be used the foursquare program
# implemented in the python library.
#
#
# #### FOURSQUARE
#
# To use foursquare, the main tool to study the location of the different parameters (restaurantes, bars, art centers, etc.) in the different neighborhoods of Madrid and Paris, it is necessary to obtain
# the data involving latitude and longitude. With the use of datasets in websites like Wikipedia (mainly because of its clearness) it is possible to obtain:
#
#
# - The divisions of Madrid and Paris in their respective neighborhoods
#
# .
#
# - The number of restaurants, bars, cultural centers, green spaces, etc.
#
# .
#
# And the use of a unique tool to gather all the information needed for both cities, gives a more precise tool to show similarities and dissimilarities since the software used is the same, reducing
# errors and misunderstandings.

# %% [markdown]
# ## 2. Ways to study the data obtained from the datasets

# %% [markdown]
# ### How we have analyzed this data (foursquare, to obtain data more precisely and number of places to compare, and with maps)
#
#
# Using foursquare it is possible to analyze the different parameters that show similarities and dissimilarities between different cities depending on the neighborhoods. To show the results in
# a more clear way, the use of different visualization tools such as maps or diagrams will be very important to comunicate in a more understanding way with the reader.
#
# For all projects it is useful to study the data using different visualization tools but, for this precise project, the use of maps will give the data scientist, the reader or everyone interested
# a more complete view and will be helpful understanding data and extracting conclusions.
#
# The visualization of distances, the relations between different neighborhoods, the visual colours for each specified parameter is important, not only for the correct understanding of the data, but
# also to understand it and extract solutions faster.

# %% [markdown]
# ## 3. How to obtain the conclusions from the data analyzed

# %% [markdown]
# ### How we have analyzed how similar they are (comparing all numbers and also comparing neighborhoods between those in the center and those outside the cities)
#
#
# Having gathered all the data needed to perform this study, it is necessary to find the best ways to compare the different parameters between neighborhoods in those cities:
#
#
# - Firstly, comparing the raw general numbers: a general view of the numbers obtained can help but can also be misleading and, eventhough it is a good start, a first approach in finding solutions, it is necessary a more thourough
# investigation on data
#
# .
#
# - Secondly, analyzing which neighborhoods in each city are similar in terms of the analyzed parameters and also the location of these neighborhoods (which will be studied thanks to the maps created perviously): it is important to analyze
# the similarities based on the number of parameters in each neighborhood but, since each city (in this case Mdrid and Paris) has a different distribution of the neighborhoods and a disctintive geography, distances also have an important
# impact on the analysis carried out
#
# .
#
# - Finally, put together every result obtained and analyse it in a more general and wider way: this project is meant to show how similar and dissimilar Madrid and Paris are based n the differences of their neighborhoods. But, to increase
# the scope of this study, it also gives some clues on how two cities that have evolved in differen countries through history, in the same continent have change and adapted to a more complex, open and diverse world as we live in
#
# .
